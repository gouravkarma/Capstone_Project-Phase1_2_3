# %%
# !pip install bs4
# !pip install requests

# %%
from bs4 import BeautifulSoup
import requests

# %%
page=requests.get('https://us.puma.com/us/en/men/shop-all-mens')

# %%
page
# Out:
# <Response [200]>

# %%
soup=BeautifulSoup(page.content)

# %%
soup
# Out:
# <!DOCTYPE html>
# ...

# %%
shoe_name=soup.find('h3',class_="w-full mobile:text-sm mobile:pr-0 font-bold text-base pr-5 line-clamp-2")
shoe_name
# Out:
# <h3 class="w-full mobile:text-sm mobile:pr-0 font-bold text-base pr-5 line-clamp-2">Suede Classic XXI Sneakers<span class="sr-only">Puma Black-Puma White</span></h3>

# %%
shoe_name.text
# Out:
# 'Suede Classic XXI SneakersPuma Black-Puma White'

# %%
shoe_name=[]
color=[]
price=[]
Review=[]

# %%
R=soup.find_all('h3',class_="w-full mobile:text-sm mobile:pr-0 font-bold text-base pr-5 line-clamp-2")
for i in R [0:10]:
    shoe_name.append(i.text)

R=soup.find_all('span',class_="group-hover:hidden group-focus-within:hidden text-puma-black-300 uppercase text-xs whitespace-nowrap")
for i in R [0:10]:
    color.append(i.text)
    
R=soup.find_all('span',class_="whitespace-nowrap text-base font-bold override:opacity-100")
for i in R [0:10]:
    price.append(i.text)

R=soup.find_all('span',class_="ml-1 pl-px text-sm")
for i in R [0:10]:
    Review.append(i.text)

# %%
print(len(shoe_name),len(color),len(price),len(Review))
# Out:
# 10 10 10 10

# %%
import pandas as pd
df=pd.DataFrame({'Shoe':shoe_name,'Color':color,'Price':price,'Review':Review})
df
# Out:
#                                                 Shoe     Color    Price  \
# 0    Suede Classic XXI SneakersPuma Black-Puma White  9 Colors   $75.00
# 1  PUMA x LAMELO BALL MB.03 Toxic Men's Basketbal...  9 Colors  $125.00
# 2  Scoot Zeros Georgia Peach Men's Basketball Sho...  9 Colors  $100.00
# 3       Suede Classic XXI SneakersPeacoat-Puma White  2 Colors   $75.00
# 4    Suede Classic XXI SneakersPuma Black-Puma Black  9 Colors   $75.00
# 5  PUMA x LAMELO BALL MB.01 Lo Men's Basketball S...  9 Colors  $115.00
# 6  Suede Classic XXI SneakersHigh Risk Red-Puma W...  2 Colors   $75.00
# 7    Suede Classic XXI SneakersSteel Gray-Puma White  9 Colors   $75.00
# 8  PUMA x LAMELO BALL MB.03 LaFrancé Men's Basket...  2 Colors  $125.00
# 9  PUMA x LAMELO BALL MB.01 Lo Men's Basketball S...  2 Colors  $120.00
#
#         Review
# 0  (84)Reviews
# 1  (84)Reviews
# 2  (84)Reviews
# 3   (2)Reviews
# 4  (84)Reviews
# 5  (84)Reviews
# 6   (2)Reviews
# 7  (84)Reviews
# 8   (1)Reviews
# ...

# %%
df.to_csv('puma.csv')

# %%
from bs4 import BeautifulSoup
import requests

# %%
page=requests.get('https://www.skechers.com/men/shoes/')

# %%
page
# Out:
# <Response [403]>

# %%
soup=BeautifulSoup(page.content)

# %%
from bs4 import BeautifulSoup
import requests

# %%
page=requests.get('https://www.columbia.com/c/shoes-boots-mens/?icpa=mlp&icid=visnav&icsa=ALL&prid=vn_prodcateg&icst=visnav&crid=footwear-shopmens&icca=btn')

# %%
page
# Out:
# <Response [200]>

# %%
soup=BeautifulSoup(page.content)

# %%
shoe_name=soup.find('a',class_="link js-tile-link")
shoe_name
# Out:
# <a class="link js-tile-link" href="/p/mens-gunnison-ii-omni-heat-boot-1862291.html?dwvar_1862291_color=231" itemprop="url">Men's Gunnison™ II Omni-Heat™ Boot</a>

# %%
shoe_name.text
# Out:
# "Men's Gunnison™ II Omni-Heat™ Boot"

# %%
shoe_name=[]
Review=[]

# %%
R=soup.find_all('a',class_="link js-tile-link")
for i in R [0:10]:
    shoe_name.append(i.text)

R=soup.find_all('div',class_="product-rating__count pl-1")
for i in R [0:10]:
    Review.append(i.text)

# %%
print(len(shoe_name),len(Review))
# Out:
# 10 10

# %%
import pandas as pd
df=pd.DataFrame({'Shoe':shoe_name,'Review':Review})
df
# Out:
#                                                 Shoe  \
# 0                 Men's Gunnison™ II Omni-Heat™ Boot
# 1                           Men's Fairhaven™ Slipper
# 2                   Men’s Fairbanks™ Omni-Heat™ Boot
# 3                  Men's Firecamp™ Fleece Lined Shoe
# 4     Men's Omni-Heat™ Lazy Bend™ Weekender Mid Shoe
# 5                           Men's Peakfreak™ II Shoe
# 6                Men's Firecamp™ III Waterproof Shoe
# 7  Men’s Newton Ridge™ Plus II Waterproof Hiking ...
# 8                 Men's Telluron™ Omni-Heat™ II Boot
# 9                   Men's Expeditionist™ Shield Boot
#
#                                               Review
# 0   \n4.388 out of 5 (260 Customer Reviews)\n(260)\n
# 1   \n4.659 out of 5 (173 Customer Reviews)\n(173)\n
# 2  \n4.417 out of 5 (1,426 Customer Reviews)\n(1,...
# 3   \n4.331 out of 5 (523 Customer Reviews)\n(523)\n
# 4     \n4.577 out of 5 (26 Customer Reviews)\n(26)\n
# 5     \n4.333 out of 5 (21 Customer Reviews)\n(21)\n
# ...

# %%
df.to_csv('Columbia.csv')

# %%
from bs4 import BeautifulSoup
import requests

# %%
page=requests.get('https://www.woodlandworldwide.com/product-list/MEN_SAFETY_SHOES')

# %%
page
# Out:
# <Response [200]>

# %%
soup=BeautifulSoup(page.content)

# %%
shoe_name=soup.find('div',class_="productcardplp_productname__F8lks")
shoe_name

# %%
shoe_name=[]
Price=[]

# %%
R=soup.find_all('p',class_="productcardplp_productname__F8lks")
for i in R [0:10]:
    shoe_name.append(i.text)

R=soup.find_all('p',class_="productcardplp_productprice__jdlz6")
for i in R [0:10]:
    Price.append(i.text)

# %%
print(len(shoe_name),len(Price))
# Out:
# 0 0
