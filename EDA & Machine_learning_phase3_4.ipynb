# %%
import pandas as pd
import numpy as np
import seaborn as sns 
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')

# %%
df=pd.read_csv('Merge.csv')
df
# Out:
#    ShoeName Category(Men/Women)  no of colors  price  count_of_sizes  colors1  \
# 0      Nike                 men             4   1999               7    black
# 1    adidas               women             5   2999               8    white
# 2      pump               women             8   1599               9     grey
# 3  skechers               women             3   2199               8    brown
# 4  columbia                 men             7   1999               9    white
# 5  woodland                 men             2   3999               9    white
# 6      Nike                 men             9   1599               7    black
# 7    adidas                 men             9   1699               8    brown
# 8      pump                 men             3   3000               7    black
#
#    color2  color3  color4  color5  Style code  eviews   Size    comfort  \
# 0    grey    white  brown     red      Casual     141      8       best
# ...

# %%
df.shape
# Out:
# (9, 16)

# %%
df.dtypes
# Out:
# ShoeName               object
# Category(Men/Women)    object
# no of colors            int64
# price                   int64
# count_of_sizes          int64
#  colors1               object
#  color2                object
#  color3                object
# color4                 object
#  color5                object
#  Style code            object
# eviews                  int64
#  Size                   int64
#  comfort               object
# quality                object
#  star rating            int64
# dtype: object

# %%
df.columns
# Out:
# Index(['ShoeName', 'Category(Men/Women)', 'no of colors', 'price',
#        'count_of_sizes', ' colors1', ' color2', ' color3 ', 'color4',
#        ' color5', ' Style code', 'eviews', ' Size', ' comfort', 'quality',
#        ' star rating  '],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9 entries, 0 to 8
# Data columns (total 16 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   ShoeName             9 non-null      object
#  1   Category(Men/Women)  9 non-null      object
#  2   no of colors         9 non-null      int64
#  3   price                9 non-null      int64
#  4   count_of_sizes       9 non-null      int64
#  5    colors1             9 non-null      object
#  6    color2              9 non-null      object
#  7    color3              9 non-null      object
#  8   color4               9 non-null      object
#  9    color5              9 non-null      object
#  10   Style code          9 non-null      object
#  11  eviews               9 non-null      int64
#  12   Size                9 non-null      int64
#  13   comfort             9 non-null      object
#  14  quality              9 non-null      object
# ...

# %%
df.isnull()
# Out:
#    ShoeName  Category(Men/Women)  no of colors  price  count_of_sizes  \
# 0     False                False         False  False           False
# 1     False                False         False  False           False
# 2     False                False         False  False           False
# 3     False                False         False  False           False
# 4     False                False         False  False           False
# 5     False                False         False  False           False
# 6     False                False         False  False           False
# 7     False                False         False  False           False
# 8     False                False         False  False           False
#
#     colors1   color2   color3   color4   color5   Style code  eviews   Size  \
# 0     False    False     False   False    False        False   False  False
# 1     False    False     False   False    False        False   False  False
# ...

# %%
df.isnull().sum()
# Out:
# ShoeName               0
# Category(Men/Women)    0
# no of colors           0
# price                  0
# count_of_sizes         0
#  colors1               0
#  color2                0
#  color3                0
# color4                 0
#  color5                0
#  Style code            0
# eviews                 0
#  Size                  0
#  comfort               0
# quality                0
#  star rating           0
# dtype: int64

# %%
df.describe()
# Out:
#        ShoeName  Category(Men/Women)  no of colors        price  \
# count  9.000000             9.000000      9.000000     9.000000
# mean   2.111111             0.333333      5.555556  2343.555556
# std    1.763834             0.500000      2.743680   820.330286
# min    0.000000             0.000000      2.000000  1599.000000
# 25%    1.000000             0.000000      3.000000  1699.000000
# 50%    2.000000             0.000000      5.000000  1999.000000
# 75%    3.000000             1.000000      8.000000  2999.000000
# max    5.000000             1.000000      9.000000  3999.000000
#
#        count_of_sizes      eviews      Size   star rating
# count        9.000000    9.000000  9.000000        9.000000
# mean         8.000000  144.111111  8.222222        4.333333
# std          0.866025   61.790866  0.833333        0.866025
# min          7.000000   45.000000  7.000000        3.000000
# 25%          7.000000  141.000000  8.000000        4.000000
# ...

# %%
df.quality.unique()
# Out:
# array(['good', 'nice'], dtype=object)

# %%
df.quality.value_counts()
# Out:
# good    7
# nice    2
# Name: quality, dtype: int64

# %%
sns.heatmap(df.isnull()) # there is no null value present in given data.
# Out:
# <AxesSubplot:>

# %%
dfcor=df.corr()

# %%
dfcor
# Out:
#                      ShoeName  Category(Men/Women)  no of colors     price  \
# ShoeName             1.000000             0.236228     -0.582603  0.583689
# Category(Men/Women)  0.236228             1.000000     -0.060746 -0.071211
# no of colors        -0.582603            -0.060746      1.000000 -0.784458
# price                0.583689            -0.071211     -0.784458  1.000000
# count_of_sizes       0.572822             0.288675      0.052607  0.175775
# eviews               0.058365             0.059340     -0.057183  0.335262
#  Size                0.151186             0.100000     -0.060746  0.367697
#  star rating        -0.109109            -0.577350     -0.192893  0.293368
#
#                      count_of_sizes    eviews      Size   star rating
# ShoeName                   0.572822  0.058365  0.151186       -0.109109
# Category(Men/Women)        0.288675  0.059340  0.100000       -0.577350
# no of colors               0.052607 -0.057183 -0.060746       -0.192893
# ...

# %%
sns.heatmap(dfcor)
# Out:
# <AxesSubplot:>

# %%
plt.figure(figsize=(6,4))
sns.heatmap(dfcor,cmap='Blues',annot=True)
# Out:
# <AxesSubplot:>

# %%
plt.figure(figsize=(10,6))
sns.heatmap(dfcor,cmap='YlOrRd_r',annot=True)
# Out:
# <AxesSubplot:>

# %%
df.columns
# Out:
# Index(['ShoeName', 'Category(Men/Women)', 'no of colors', 'price',
#        'count_of_sizes', ' colors1', ' color2', ' color3 ', 'color4',
#        ' color5', ' Style code', 'eviews', ' Size', ' comfort', 'quality',
#        ' star rating  '],
#       dtype='object')

# %%
df['ShoeName'].plot.box()
# Out:
# <AxesSubplot:>

# %%
df['Category(Men/Women)'].plot.box()
# Out:
# <AxesSubplot:>

# %%
df.plot(kind='box',subplots=True,layout=(2,6),figsize=(10,10))
# Out:
# ShoeName                  AxesSubplot(0.125,0.53;0.110714x0.35)
# Category(Men/Women)    AxesSubplot(0.257857,0.53;0.110714x0.35)
# no of colors           AxesSubplot(0.390714,0.53;0.110714x0.35)
# price                  AxesSubplot(0.523571,0.53;0.110714x0.35)
# count_of_sizes         AxesSubplot(0.656429,0.53;0.110714x0.35)
# eviews                 AxesSubplot(0.789286,0.53;0.110714x0.35)
#  Size                     AxesSubplot(0.125,0.11;0.110714x0.35)
#  star rating           AxesSubplot(0.257857,0.11;0.110714x0.35)
# dtype: object

# %%
df.plot(kind='box',subplots=True,layout=(3,4),figsize=(10,10))
# Out:
# ShoeName                  AxesSubplot(0.125,0.653529;0.168478x0.226471)
# Category(Men/Women)    AxesSubplot(0.327174,0.653529;0.168478x0.226471)
# no of colors           AxesSubplot(0.529348,0.653529;0.168478x0.226471)
# price                  AxesSubplot(0.731522,0.653529;0.168478x0.226471)
# count_of_sizes            AxesSubplot(0.125,0.381765;0.168478x0.226471)
# eviews                 AxesSubplot(0.327174,0.381765;0.168478x0.226471)
#  Size                  AxesSubplot(0.529348,0.381765;0.168478x0.226471)
#  star rating           AxesSubplot(0.731522,0.381765;0.168478x0.226471)
# dtype: object

# %%
df.plot(kind='box',subplots=True,layout=(4,3),figsize=(15,15))
# Out:
# ShoeName                  AxesSubplot(0.125,0.712609;0.227941x0.167391)
# Category(Men/Women)    AxesSubplot(0.398529,0.712609;0.227941x0.167391)
# no of colors           AxesSubplot(0.672059,0.712609;0.227941x0.167391)
# price                     AxesSubplot(0.125,0.511739;0.227941x0.167391)
# count_of_sizes         AxesSubplot(0.398529,0.511739;0.227941x0.167391)
# eviews                 AxesSubplot(0.672059,0.511739;0.227941x0.167391)
#  Size                      AxesSubplot(0.125,0.31087;0.227941x0.167391)
#  star rating            AxesSubplot(0.398529,0.31087;0.227941x0.167391)
# dtype: object

# %%
sns.distplot(df['ShoeName'])
# Out:
# <AxesSubplot:xlabel='ShoeName', ylabel='Density'>

# %%
sns.distplot(df['price'])
# Out:
# <AxesSubplot:xlabel='price', ylabel='Density'>

# %%
sns.distplot(df['Category(Men/Women)'])
# Out:
# <AxesSubplot:xlabel='Category(Men/Women)', ylabel='Density'>

# %%
df.plot(kind='kde',subplots=True,layout=(2,6),figsize=(15,6))
# Out:
# array([[<AxesSubplot:ylabel='Density'>, <AxesSubplot:ylabel='Density'>,
#         <AxesSubplot:ylabel='Density'>, <AxesSubplot:ylabel='Density'>,
#         <AxesSubplot:ylabel='Density'>, <AxesSubplot:ylabel='Density'>],
#        [<AxesSubplot:ylabel='Density'>, <AxesSubplot:ylabel='Density'>,
#         <AxesSubplot:ylabel='Density'>, <AxesSubplot:ylabel='Density'>,
#         <AxesSubplot:ylabel='Density'>, <AxesSubplot:ylabel='Density'>]],
#       dtype=object)

# %%
plt.scatter(df['ShoeName'],df['Category(Men/Women)'])

# %%
sns.pairplot(df)

# %%
# phase 4

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import sklearn
from sklearn.linear_model import LogisticRegression 
from sklearn.metrics import accuracy_score,confusion_matrix,classification_report
from sklearn.model_selection import train_test_split

import warnings
warnings.filterwarnings('ignore')

# %%
df=pd.read_csv('Merge.csv')
df.head(5)
# Out:
#    ShoeName Category(Men/Women)  no of colors  price  count_of_sizes  colors1  \
# 0      Nike                 men             4   1999               7    black
# 1    adidas               women             5   2999               8    white
# 2      pump               women             8   1599               9     grey
# 3  skechers               women             3   2199               8    brown
# 4  columbia                 men             7   1999               9    white
#
#    color2  color3  color4  color5  Style code  eviews   Size    comfort  \
# 0    grey    white  brown     red      Casual     141      8       best
# 1   brown      red  black   white      formal     201      9  wonderful
# 2   black    white  brown     red       sport     201      9  wonderful
# 3     red    black  white     red     sheaker      45      7  fantastic
# 4   brown      red    red    blue      casual     191      9  wonderful
#
#   quality   star rating
# 0    good               5
# ...

# %%
df.dtypes
# Out:
# ShoeName               object
# Category(Men/Women)    object
# no of colors            int64
# price                   int64
# count_of_sizes          int64
#  colors1               object
#  color2                object
#  color3                object
# color4                 object
#  color5                object
#  Style code            object
# eviews                  int64
#  Size                   int64
#  comfort               object
# quality                object
#  star rating            int64
# dtype: object

# %%
sns.pairplot(df)

# %%
plt.figure(figsize=(20,10))
sns.heatmap(df.corr(),annot=True)
plt.show()

# %%
from sklearn.preprocessing import OneHotEncoder,LabelEncoder
le=LabelEncoder()
list1=['ShoeName', 'Category(Men/Women)']
for val in list1:
    df[val]=le.fit_transform(df[val].astype(str))

# %%
df
# Out:
#    ShoeName  Category(Men/Women)  no of colors  price  count_of_sizes  \
# 0         0                    0             4   1999               7
# 1         1                    1             5   2999               8
# 2         3                    1             8   1599               9
# 3         4                    1             3   2199               8
# 4         2                    0             7   1999               9
# 5         5                    0             2   3999               9
# 6         0                    0             9   1599               7
# 7         1                    0             9   1699               8
# 8         3                    0             3   3000               7
#
#    colors1  color2  color3  color4  color5  Style code  eviews   Size  \
# 0    black    grey    white  brown     red      Casual     141      8
# 1    white   brown      red  black   white      formal     201      9
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9 entries, 0 to 8
# Data columns (total 16 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   ShoeName             9 non-null      int32
#  1   Category(Men/Women)  9 non-null      int32
#  2   no of colors         9 non-null      int64
#  3   price                9 non-null      int64
#  4   count_of_sizes       9 non-null      int64
#  5    colors1             9 non-null      object
#  6    color2              9 non-null      object
#  7    color3              9 non-null      object
#  8   color4               9 non-null      object
#  9    color5              9 non-null      object
#  10   Style code          9 non-null      object
#  11  eviews               9 non-null      int64
#  12   Size                9 non-null      int64
#  13   comfort             9 non-null      object
#  14  quality              9 non-null      object
# ...

# %%
df.describe()
# Out:
#        ShoeName  Category(Men/Women)  no of colors        price  \
# count  9.000000             9.000000      9.000000     9.000000
# mean   2.111111             0.333333      5.555556  2343.555556
# std    1.763834             0.500000      2.743680   820.330286
# min    0.000000             0.000000      2.000000  1599.000000
# 25%    1.000000             0.000000      3.000000  1699.000000
# 50%    2.000000             0.000000      5.000000  1999.000000
# 75%    3.000000             1.000000      8.000000  2999.000000
# max    5.000000             1.000000      9.000000  3999.000000
#
#        count_of_sizes      eviews      Size   star rating
# count        9.000000    9.000000  9.000000        9.000000
# mean         8.000000  144.111111  8.222222        4.333333
# std          0.866025   61.790866  0.833333        0.866025
# min          7.000000   45.000000  7.000000        3.000000
# 25%          7.000000  141.000000  8.000000        4.000000
# ...

# %%
df.skew()
# Out:
# ShoeName               0.313122
# Category(Men/Women)    0.857143
# no of colors           0.132955
# price                  1.142129
# count_of_sizes         0.000000
# eviews                -0.935186
#  Size                 -0.500571
#  star rating          -0.824786
# dtype: float64

# %%
sns.heatmap(df.isnull())
# Out:
# <AxesSubplot:>

# %%
dfcor=df.corr()
dfcor
# Out:
#                      ShoeName  Category(Men/Women)  no of colors     price  \
# ShoeName             1.000000             0.236228     -0.582603  0.583689
# Category(Men/Women)  0.236228             1.000000     -0.060746 -0.071211
# no of colors        -0.582603            -0.060746      1.000000 -0.784458
# price                0.583689            -0.071211     -0.784458  1.000000
# count_of_sizes       0.572822             0.288675      0.052607  0.175775
# eviews               0.058365             0.059340     -0.057183  0.335262
#  Size                0.151186             0.100000     -0.060746  0.367697
#  star rating        -0.109109            -0.577350     -0.192893  0.293368
#
#                      count_of_sizes    eviews      Size   star rating
# ShoeName                   0.572822  0.058365  0.151186       -0.109109
# Category(Men/Women)        0.288675  0.059340  0.100000       -0.577350
# no of colors               0.052607 -0.057183 -0.060746       -0.192893
# ...

# %%
sns.heatmap(dfcor)
# Out:
# <AxesSubplot:>

# %%
plt.figure(figsize=(20,10))
sns.heatmap(dfcor,cmap='Blues',annot=True)
# Out:
# <AxesSubplot:>

# %%
plt.figure(figsize=(20,10))
sns.heatmap(dfcor,cmap='YlOrRd_r',annot=True)
# Out:
# <AxesSubplot:>

# %%
corr_hmap=df.corr()
plt.figure(figsize=(20,6))
sns.heatmap(corr_hmap,annot=True)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
df.plot(kind='box',subplots=True,layout=(4,6))
# Out:
# ShoeName                  AxesSubplot(0.125,0.712609;0.110714x0.167391)
# Category(Men/Women)    AxesSubplot(0.257857,0.712609;0.110714x0.167391)
# no of colors           AxesSubplot(0.390714,0.712609;0.110714x0.167391)
# price                  AxesSubplot(0.523571,0.712609;0.110714x0.167391)
# count_of_sizes         AxesSubplot(0.656429,0.712609;0.110714x0.167391)
# eviews                 AxesSubplot(0.789286,0.712609;0.110714x0.167391)
#  Size                     AxesSubplot(0.125,0.511739;0.110714x0.167391)
#  star rating           AxesSubplot(0.257857,0.511739;0.110714x0.167391)
# dtype: object

# %%
df.plot(kind='box',subplots=True,layout=(4,6))
# Out:
# ShoeName                  AxesSubplot(0.125,0.712609;0.110714x0.167391)
# Category(Men/Women)    AxesSubplot(0.257857,0.712609;0.110714x0.167391)
# no of colors           AxesSubplot(0.390714,0.712609;0.110714x0.167391)
# price                  AxesSubplot(0.523571,0.712609;0.110714x0.167391)
# count_of_sizes         AxesSubplot(0.656429,0.712609;0.110714x0.167391)
# eviews                 AxesSubplot(0.789286,0.712609;0.110714x0.167391)
#  Size                     AxesSubplot(0.125,0.511739;0.110714x0.167391)
#  star rating           AxesSubplot(0.257857,0.511739;0.110714x0.167391)
# dtype: object

# %%
A=df.iloc[:,:]
A
# Out:
#    ShoeName  Category(Men/Women)  no of colors  price  count_of_sizes  \
# 0         0                    0             4   1999               7
# 1         1                    1             5   2999               8
# 2         3                    1             8   1599               9
# 3         4                    1             3   2199               8
# 4         2                    0             7   1999               9
# 5         5                    0             2   3999               9
# 6         0                    0             9   1599               7
# 7         1                    0             9   1699               8
# 8         3                    0             3   3000               7
#
#    colors1  color2  color3  color4  color5  Style code  eviews   Size  \
# 0    black    grey    white  brown     red      Casual     141      8
# 1    white   brown      red  black   white      formal     201      9
# ...

# %%
x=df.iloc[:,0:-1]
x
# Out:
#    ShoeName  Category(Men/Women)  no of colors  price  count_of_sizes  \
# 0         0                    0             4   1999               7
# 1         1                    1             5   2999               8
# 2         3                    1             8   1599               9
# 3         4                    1             3   2199               8
# 4         2                    0             7   1999               9
# 5         5                    0             2   3999               9
# 6         0                    0             9   1599               7
# 7         1                    0             9   1699               8
# 8         3                    0             3   3000               7
#
#    colors1  color2  color3  color4  color5  Style code  eviews   Size  \
# 0    black    grey    white  brown     red      Casual     141      8
# 1    white   brown      red  black   white      formal     201      9
# ...

# %%
y=df.iloc[:,-1]
y
# Out:
# 0    5
# 1    4
# 2    4
# 3    3
# 4    5
# 5    5
# 6    5
# 7    3
# 8    5
# Name:  star rating  , dtype: int64

# %%
x.shape
# Out:
# (9, 15)

# %%
y.shape
# Out:
# (9,)

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=.33,random_state=42)

# %%
from sklearn.linear_model import LinearRegression
lm = LinearRegression()
lm
# Out:
# LinearRegression()
